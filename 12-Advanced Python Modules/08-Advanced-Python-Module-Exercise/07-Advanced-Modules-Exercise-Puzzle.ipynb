# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Advanced Modules Exercise Puzzle
#
# It's time to test your new skills, this puzzle project will combine multiple skills sets, including unzipping files with Python, using os module to automatically search through lots of files.
#
# ## Your Goal
#
# This is a puzzle, so we don't want to give you too much guidance and instead have you figure out things on your own.
#
# There is a .zip file called 'unzip_me_for_instructions.zip', unzip it, open the .txt file with Python, read the instructions and see if you can figure out what you need to do!
#
# **If you get stuck or don't know where to start, here is a [guide/hints](https://docs.google.com/document/d/1JxydUr4n4fSR0EwwuwT-aHia-yPK6r-oTBuVT2sqheo/edit?usp=sharing)**

# %%
import zipfile
import os
import re

# %%
zip_object = zipfile.ZipFile('unzip_me_for_instructions.zip', 'r')

# %%
zip_object.extractall('Unzipped_instructions')

# %%
pwd
# Out:
# 'c:\\GitHub\\Complete-Python-3-Bootcamp\\12-Advanced Python Modules\\08-Advanced-Python-Module-Exercise'

# %%
path = 'c:\\GitHub\\Complete-Python-3-Bootcamp\\12-Advanced Python Modules\\08-Advanced-Python-Module-Exercise\\extracted_content'

# %%
pattern = r'\d{3}-\d{3}-\d{4}'

# %%
#testing
f = open('instructions.txt', 'r')
content = f.read()
print(content)
f.close()
# Out:
# Good work on unzipping the file!
# You should now see 5 folders, each with a lot of random .txt files.
# Within one of these text files is a telephone number formated ###-###-####
# Use the Python os module and regular expressions to iterate through each file, open it, and search for a telephone number.
# Good luck!

# %%
#results = []

#for root, dirs, files in os.walk(path):
    #for filename in files:
        #f = open(filename, 'r')
        #contents = f.read()
        #re.search(pattern, contents)
        #f.close()

# %%
def search(file, pattern= pattern):
    f = open(file,'r')
    contents = f.read()

    if re.search(pattern,contents):
        return re.search(pattern,contents)
    else:
        return None

# %%
results = []

# %%
for folder, sub_folders, files in os.walk(os.getcwd()+'\\extracted_content'):   #getcwd = get current working directory. + folder where unzipped content is
    
    for f in files:
        full_path = folder + '\\'+f     # to avoid file path error. full_path = the folder + the file itself

        results.append(search(full_path)) # uses the search function from cell above. Returns what i am looking for if found and appends it to the empty list 'results'

# %%
results
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  <re.Match object; span=(1062, 1074), match='719-266-2837'>,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']
